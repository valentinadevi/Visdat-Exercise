# %% [markdown]
# # **Matplotlib 05**
# Source : [Indonesia Belajar](https://youtu.be/4o4FhsQYOPY)

# %% [markdown]
# # **Belajar Bar Plot | Bar Chart**

# %% [markdown]
# # Impert Modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.2
# 1.24.2

# %% [markdown]
# # Simple Bar Plot

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# - Bar plot biasanya digunakan untuk melakukan plotting data yang bersifat categorical atau discrete.
# - plt.bar() digunakan untuk membuat bar plot.
# - Setidaknya ada dua parameter yang harus kita masukkan, yaitu: kategorical data dan dan numeric data.
# - kategorical data adalah parameter akan digunakan sebagai label.
# - Numeric data adalah parameter yang akan digunakan sebagai nilai.

# %%
plt.bar(kategori, data)
plt.grid()

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# # Pengaturan Grid dan Color

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# - Pada parameter plt.bar(), Color dan alpha digunakan untuk mengatur warna dan opacity bar.
# - Pada parameter plt.grid(), linestyle dan linewidth digunakan untuk mengatur bentuk dan ketebalan garis.
# - Pada parameter plt.grid(), Axis digunakan untuk mengatur garis agar dapat berasosiasi dengan sumbu.
# - Pada parameter plt.grid(), Alpha digunakan untuk mengatur opacity garis bantu.

# %%
# Membuat bar plot
plt.bar(kategori, 
        data, 
        color='red',  # Warna batang
        alpha=0.25)    # Tingkat transparansi

# Menambahkan garis-garis kisi (grid)
plt.grid(linestyle='--', 
         linewidth=2, 
         axis='y',  # Menampilkan grid hanya pada sumbu y
         alpha=0.50)  # Tingkat transparansi grid

# Menambahkan label pada sumbu x dan y
plt.xlabel('Kategori')
plt.ylabel('Jumlah')

# Menambahkan judul plot
plt.title('Contoh Bar Plot')

# Menampilkan plot
plt.show()

# %% [markdown]
# # Horizontal Bar Plot

# %% [markdown]
# - Jika kita ingin membuat bar plot secara horizontal kita dapat menggunakan fungsi plt.barh().
# - Untuk membalik urutan bar, kita dapat memanfaatkan slicing.

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
# Membuat horizontal bar plot
plt.barh(kategori, data)

# Menambahkan garis-garis kisi (grid)
plt.grid(linestyle='--', 
         linewidth=1, 
         axis='x',  # Menampilkan grid hanya pada sumbu x
         alpha=0.75)  # Tingkat transparansi grid

# Menambahkan label pada sumbu x dan y
plt.xlabel('Jumlah')
plt.ylabel('Kategori')

# Menambahkan judul plot
plt.title('Contoh Horizontal Bar Plot')

# Menampilkan plot
plt.show()

# %% [markdown]
# # Stacked Bar Plot

# %% [markdown]
# - Stacked Bar Plot sangat mirip dengan bar plot lainnya, hanya saja disini terdapat lebih dari satu data, maka data lainnya akan ditumpuk.
# - Dengan begitu, diperlukan parameter-parameter tambahan, bottom, digunakan untuk menumpuk data dan menentukan posisi atas bawah.
# - Jika tidak menggunakan parameter bottom maka plotting data1 akan ditimpa data2.

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
# Membuat stacked bar plot dengan menumpuk data2 di atas data1
plt.bar(kategori, data1, label='Data 1')
plt.bar(kategori, data2, label='Data 2', bottom=data1)  # Parameter bottom digunakan untuk menentukan posisi data2 di atas data1

# Menambahkan legenda untuk membedakan antara Data 1 dan Data 2
plt.legend()

# Menambahkan garis-garis kisi (grid)
plt.grid(linestyle='--', 
         linewidth=1, 
         axis='y',  # Menampilkan grid hanya pada sumbu y
         alpha=0.75)  # Tingkat transparansi grid

# Menambahkan label pada sumbu x dan y
plt.xlabel('Kategori')
plt.ylabel('Jumlah')

# Menambahkan judul plot
plt.title('Contoh Stacked Bar Plot')

# Menampilkan plot
plt.show()

# %% [markdown]
# # Grouped Bar Plot

# %%
data1 = [25,85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

#Array untuk deret bilangan
x = np.arange(len(kategori)) 
x
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# - jika ingin membuat grouped Bar Plot, kita harus mengatur width (%) terlebih dahulu.
# - Semakin kecil width, semakin tipis bar yang dibuat, dsehingga jarak antara bar semakin lebar.
# - Variabel x yang telah kita buat tadi akan menjadi titik tengah kedua barplot, sehingga, posisi data 1 yaitu x dikurangi oleh width dibagi dua.
# Dan, posisi data 2 yaitu X ditambah oleh width dibagi dua.
# - Parameter dibawah ini kurang lebih memiliki arti (posisi, nilai data, lebar, dan nama label).

# %%
# Lebar setiap bar dalam grouped bar plot
width = 0.35

# Mendapatkan indeks untuk setiap kategori
x = np.arange(len(kategori))

# Membuat Grouped Bar Plot
plt.bar(x - width/2, data1, width, label='Data 1')
plt.bar(x + width/2, data2, width, label='Data 2')

# Menentukan label untuk setiap bar
plt.xticks(x, kategori)

# Menambahkan grid pada sumbu y dengan garis putus-putus
plt.grid(linestyle='--', linewidth=1, axis='y', alpha=0.75)

# Menambahkan label pada sumbu x dan y
plt.xlabel('Kategori')
plt.ylabel('Jumlah')

# Menambahkan judul pada Grouped Bar Plot
plt.title('Contoh Grouped Bar Plot')

# Menampilkan legenda
plt.legend()

# Menampilkan Grouped Bar Plot
plt.show()
