# %% [markdown]
# # **Matplotlib 07**
# Source : [Indonesia Belajar](https://youtu.be/MDG5v33O6F4)

# %% [markdown]
# # **Belajar Table Plot | Table Chart**

# %% [markdown]
# # Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

#Cek Versi
print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.2
# 1.24.2

# %% [markdown]
# # Sample Data

# %%
# membuat list 2 dimensi
data_uas=[
    ['Bejo', 70],
    ['Tejo', 83],
    ['Cecep', 62],
    ['Wati', 74],
    ['Karti', 71]
]

data_uas
# Out:
# [['Bejo', 70], ['Tejo', 83], ['Cecep', 62], ['Wati', 74], ['Karti', 71]]

# %% [markdown]
# # Table Plot dengan OO Style

# %% [markdown]
# - Data tabular yang ditampilkan tidak dalam format dataframe, melainkan menggunakan figure dan axes.
# - Pemanggilan fungsi plt.table() membutuhkan dua parameter.
# - Parameter pertama yaitu celltext berisi data uas.
# - Parameter kedua yaitu loc/location merupakan Penempatan tabel plot.

# %%
fig, ax = plt.subplots()

table = plt.table(cellText=data_uas, 
                  loc='center')

# atribut dari objek table
table.set_fontsize(14) # untuk mengatur ukuran huruf
table.scale(1, 4) # untuk mengatur ukuran kolom, baris

ax.axis(False) # untuk menghilangkan axis (bagian dari axes)

plt.show()

# %% [markdown]
# # Table Plot dengan pyplot Style
# - Mirip dengan penjelasan oo style, hanya saja memiliki perbedaan yang cukup jelas saat kita ingin menghilangkan axisnya.
# - Axis merupakan bagian dari axes dan jika kita tidak mendeklarasikan axes, maka kita tidak bisa men-disable axis.
# - Kita dapat memanfaatkan fungsi plt.gca().
# - Fungsi plt.gca() (get current access) dapat mendapatkan referensi ke objek yang sedang aktif.

# %%
table = plt.table(cellText=data_uas, 
                  loc='center')

table.set_fontsize(14)
table.scale(1, 4) # mengatur ukuran kolom, baris

# disable axis
ax = plt.gca()
ax.axis(False)

plt.show()
