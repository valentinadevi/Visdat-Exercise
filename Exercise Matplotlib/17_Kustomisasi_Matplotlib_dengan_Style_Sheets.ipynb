# %% [markdown]
# # **Matplotlib 17**
# Source : [Indonesia Belajar](https://youtu.be/fXY29PQHt2A)

# %% [markdown]
# ## **Kustomisasi Matplotlib dengan Style Sheets**

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as seaborn
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.8.2
# 1.24.2

# %% [markdown]
# ### Predefined Styles

# %% [markdown]
# - Untuk melihat predefined style kita memanggil fungsi plt.style.available.
# - Untuk menggunakan predefined style kita menggunakan fungsi plt.style.use().

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %% [markdown]
# - Membuat 15 buat nilai random yang ditampung kedalam variabel x.
# - Membuat 2 buah plot.
# - Plot pertama akan dilakukan plotting variabel x terhadap nilai x juga.
# - Parameter 'bs-' pada plotting pertama berarti 'blue, square, -'.
# - Plot kedua akan dilakukan plotting variabel x terhadap nilai log x.
# - Parameter 'ro-' pada plotting kedua berarti 'red, dots, -'.

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# ### Membuat Style sendiri

# %% [markdown]
# - Pada contoh kali ini saya akan membuat style dengan konfigurasi seperti berikut:
#
# axes.titlesize : 22 axes.labelsize : 18 lines.linewidth : 3 lines.markersize : 9 xtick.labelsize : 15 ytick.labelsize : 15
#
# - Konfigurasi tersebut akan saya simpan kedalam sebuah file yang bernama  newStyle.
# - Ekstensi untuk style matplotlib adalah mplstyle.
# Simbol './' menandakan directory yang sedang aktif saat ini.

# %%
plt.style.use('./newStyle.mplstyle')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')
plt.title('Contoh Plot')

plt.show()

# %% [markdown]
# # **Menerapkan multiple style**
# - Dalam matplotlib mungkin bagi kita untuk menerapkan lebih dari satu style.
# - Urutan style berpengaruh terhadap penerapan/ overlapping.**

# %%
# Set Seaborn style
seaborn.set_style('whitegrid')  # Choose any Seaborn style you prefer

# Use the 'dark_background' style from Matplotlib
plt.style.use('dark_background')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# ### **Menerapkan temporary styling**
# - Untuk menerapkan style sementara, kita bisa memasukkan style yang kita inginkan kedalam scope with.**

# %%
plt.style.use('ggplot')

plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')

plt.show()

# %%
plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %% [markdown]
# - Nah plotting terakhir ini tidak mengadopsi style dark_background karena style dark_background diterapkan secara sementara.
